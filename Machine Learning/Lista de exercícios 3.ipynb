# %%
# %pip install --upgrade pip
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# %pip install tensorflow
#%pip install scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.decomposition import PCA

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(-1, 784) / 255
X_test = X_test.reshape(-1, 784) / 255

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(X_train.shape)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# (60000, 784)
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.96      1.00      0.98      1135
#            2       0.98      0.97      0.97      1032
#            3       0.96      0.97      0.96      1010
#            4       0.98      0.97      0.97       982
#            5       0.97      0.96      0.96       892
#            6       0.98      0.99      0.98       958
#            7       0.96      0.96      0.96      1028
#            8       0.99      0.94      0.96       974
#            9       0.96      0.96      0.96      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
pca = PCA(n_components=0.95)

X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train_pca, y_train)

y_pred = model.predict(X_test_pca)

print(X_train_pca.shape)
print("\nClassification Report:\n", classification_report(y_test, y_pred), confusion_matrix(y_test,y_pred))
# Out:
# (60000, 154)
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.96      1.00      0.98      1135
#            2       0.98      0.97      0.97      1032
#            3       0.96      0.97      0.97      1010
#            4       0.98      0.97      0.97       982
#            5       0.97      0.96      0.97       892
#            6       0.98      0.99      0.98       958
#            7       0.96      0.97      0.97      1028
#            8       0.99      0.94      0.97       974
#            9       0.96      0.96      0.96      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
#  [[ 974    1    1    0    0    1    2    1    0    0]
#  [   0 1132    2    0    0    0    1    0    0    0]
#  [   9    8  997    2    1    0    0   14    1    0]
#  [   1    2    3  978    1   12    0    7    3    3]
#  [   1    5    0    0  952    0    4    2    0   18]
#  [   6    1    0   11    1  860    5    1    3    4]
#  [   6    3    0    0    2    2  945    0    0    0]
#  [   0   17    5    0    1    0    0  997    0    8]
#  [   7    2    4   16    7    9    3    3  920    3]
#  [   4    4    2    9   10    2    1    9    1  967]]
